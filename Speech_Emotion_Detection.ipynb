# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk("/content/drive/MyDrive/SR1"):
  for filename in filenames:
    print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_late_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_cause_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_mouse_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_note_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_pole_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_goal_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_choice_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_numb_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_raise_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_match_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_boat_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_keep_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_lease_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_mop_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_hole_neutral.wav
# /content/drive/MyDrive/SR1/OAF_neutral/OAF_make_neutral.wav
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import random as rn
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('/content/drive/MyDrive/SR1'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
paths[:5]
# Out:
# ['/content/drive/MyDrive/SR1/OAF_neutral/OAF_late_neutral.wav',
#  '/content/drive/MyDrive/SR1/OAF_neutral/OAF_cause_neutral.wav',
#  '/content/drive/MyDrive/SR1/OAF_neutral/OAF_mouse_neutral.wav',
#  '/content/drive/MyDrive/SR1/OAF_neutral/OAF_note_neutral.wav',
#  '/content/drive/MyDrive/SR1/OAF_neutral/OAF_pole_neutral.wav']

# %%
labels[:5]
# Out:
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech    label
# 0  /content/drive/MyDrive/SR1/OAF_neutral/OAF_lat...  neutral
# 1  /content/drive/MyDrive/SR1/OAF_neutral/OAF_cau...  neutral
# 2  /content/drive/MyDrive/SR1/OAF_neutral/OAF_mou...  neutral
# 3  /content/drive/MyDrive/SR1/OAF_neutral/OAF_not...  neutral
# 4  /content/drive/MyDrive/SR1/OAF_neutral/OAF_pol...  neutral

# %%
df['label'].value_counts()
# Out:
# neutral        400
# angry          400
# happy          400
# disgust        400
# sad            400
# fear           400
# ps             400
# happy (1)       10
# neutral (1)      5
# Name: label, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

label_counts = df['label'].value_counts()


plt.bar(label_counts.index, label_counts.values)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.title('Count of Each Label')
plt.show()

# %%
#def waveplot(data, sr, emotion):
#    plt.figure(figsize=(10,4))
#    plt.title(emotion, size=20)
#    librosa.display.waveplot(data, sr=sr)
#    plt.show()
    

def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()


def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
l=rn.randint(0,len(df['speech'][df['label']==emotion])-1)
path = np.array(df['speech'][df['label']==emotion])[l]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
l=rn.randint(0,len(df['speech'][df['label']==emotion])-1)
path = np.array(df['speech'][df['label']==emotion])[l]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
l=rn.randint(0,len(df['speech'][df['label']==emotion])-1)
path = np.array(df['speech'][df['label']==emotion])[l]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
l=rn.randint(0,len(df['speech'][df['label']==emotion])-1)
path = np.array(df['speech'][df['label']==emotion])[l]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
l=rn.randint(0,len(df['speech'][df['label']==emotion])-1)
path = np.array(df['speech'][df['label']==emotion])[l]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
l=rn.randint(0,len(df['speech'][df['label']==emotion])-1)
path = np.array(df['speech'][df['label']==emotion])[l]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
l=rn.randint(0,len(df['speech'][df['label']==emotion])-1)
path = np.array(df['speech'][df['label']==emotion])[l]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
l=rn.randint(0,len(df['speech']))
extract_mfcc(df['speech'][l])
# Out:
# array([-3.5188748e+02,  4.9641560e+01, -6.1168842e+00,  2.5864855e+01,
#        -1.8624905e+01, -6.3138456e+00,  3.6655397e+00, -2.4782148e+01,
#        -3.1464577e+00, -2.4554641e+00, -1.3628872e+01,  1.7012337e+01,
#        -1.3615814e+01,  8.4283705e+00,  5.6650562e+00, -7.8612943e+00,
#         3.4753823e-01, -3.2128940e+00, -8.4762640e+00, -2.1650946e+00,
#        -7.6965795e+00, -2.7319837e+00, -5.2070751e+00, -7.6064482e-02,
#         7.8334975e-01,  2.4337725e-01,  3.8323693e+00,  1.0032542e+01,
#         1.4267933e+01,  1.8021236e+01,  1.4732810e+01,  1.5603554e+01,
#         2.4182646e+00,  1.4953486e+00, -3.2594745e+00,  4.6885056e+00,
#         4.4799566e+00,  3.7156405e+00, -4.3031330e+00, -1.4060277e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-506.16553, 96.58104, 14.180532, 9.32054, 17....
# 1       [-490.27316, 95.174644, 16.884064, -6.904421, ...
# 2       [-514.2154, 100.89656, 21.901604, -0.3234141, ...
# 3       [-541.3531, 115.6594, 30.559635, 0.21497537, 1...
# 4       [-557.14905, 111.57625, 39.06124, 7.0098414, 2...
#                               ...
# 2810    [-454.20364, 93.66159, 14.078812, -0.9950412, ...
# 2811    [-440.55798, 111.68289, 20.593958, -6.648762, ...
# 2812    [-489.34702, 88.14828, 24.89036, 2.0312927, 13...
# 2813    [-480.4338, 94.40333, 21.413242, -2.883113, 9....
# 2814    [-467.13086, 90.74654, 32.921684, -7.383644, 3...
# Name: speech, Length: 2815, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2815, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2815, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2815, 9)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(123, return_sequences=False, input_shape=(40,1)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dropout(0.2),
    Dense(9, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 123)               61500
#
#  dense (Dense)               (None, 64)                7936
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 9)                 153
#
# ...
# Total params: 72,469
# Trainable params: 72,469
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, validation_split=0.2, epochs=100, batch_size=32, shuffle=True)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 8s 82ms/step - loss: 1.9996 - accuracy: 0.2537 - val_loss: 1.5336 - val_accuracy: 0.5455
# Epoch 2/100
# 57/57 [==============================] - 5s 80ms/step - loss: 1.4513 - accuracy: 0.4409 - val_loss: 0.8979 - val_accuracy: 0.6696
# Epoch 3/100
# 57/57 [==============================] - 3s 56ms/step - loss: 1.1025 - accuracy: 0.5736 - val_loss: 0.7725 - val_accuracy: 0.7694
# Epoch 4/100
# 57/57 [==============================] - 3s 57ms/step - loss: 0.9794 - accuracy: 0.6269 - val_loss: 0.5871 - val_accuracy: 0.8315
# Epoch 5/100
# 57/57 [==============================] - 4s 78ms/step - loss: 0.8099 - accuracy: 0.7129 - val_loss: 0.4389 - val_accuracy: 0.8936
# Epoch 6/100
# 57/57 [==============================] - 4s 77ms/step - loss: 0.6877 - accuracy: 0.7568 - val_loss: 0.3929 - val_accuracy: 0.9113
# Epoch 7/100
# ...

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# 18/18 [==============================] - 0s 25ms/step - loss: 0.0635 - accuracy: 0.9805

# %%
epochs = list(range(100))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Make predictions on the test data
y_pred = model.predict(x_test)

# Get the predicted class indices
predicted_class_indices = np.argmax(y_pred, axis=1)
print(predicted_class_indices)
# Out:
# 18/18 [==============================] - 1s 19ms/step
# [3 8 8 7 3 7 1 3 3 0 8 1 7 8 3 8 2 5 0 7 3 7 0 3 7 5 5 8 3 7 7 1 5 1 2 3 8
#  7 2 5 0 1 5 3 3 5 7 3 8 3 0 8 3 2 3 5 5 0 8 1 2 2 2 2 2 5 5 3 7 1 8 0 3 0
#  3 3 5 8 1 0 2 3 0 5 3 5 7 7 7 3 7 1 5 8 0 3 2 1 2 7 7 0 2 3 8 3 3 7 8 1 0
#  3 2 1 2 0 8 7 7 5 3 2 8 2 3 1 7 3 8 8 8 0 7 7 2 3 2 2 8 5 5 5 3 3 5 2 7 0
#  5 1 3 5 2 0 2 2 3 7 2 3 7 7 8 0 7 5 5 5 8 2 7 5 5 1 1 2 0 8 1 0 0 5 2 5 3
#  8 7 8 0 7 8 7 3 2 3 3 1 8 3 1 8 5 3 2 3 2 1 1 0 1 8 8 5 0 5 8 3 5 5 5 0 7
#  0 7 3 7 3 1 0 3 2 8 8 8 7 7 0 5 0 2 2 7 8 7 0 1 8 3 7 1 1 7 5 1 8 1 8 8 2
#  8 0 2 2 2 1 5 3 3 0 1 0 3 7 2 1 8 0 0 3 3 5 5 2 8 0 7 0 1 5 5 7 5 5 8 3 0
#  7 7 2 3 1 8 1 5 3 2 3 8 2 8 5 8 0 8 7 1 2 3 7 0 3 0 5 8 1 5 3 8 3 1 2 0 0
#  5 5 2 0 2 1 3 5 2 8 2 7 0 8 7 2 2 0 8 1 7 5 0 2 3 0 8 3 7 1 5 8 8 2 0 3 7
#  7 0 2 8 2 7 2 8 1 0 3 2 0 3 1 5 5 3 2 1 5 0 3 3 7 0 1 1 5 1 0 1 0 5 8 5 5
#  7 0 0 1 1 8 7 8 3 2 8 8 8 3 3 5 3 7 2 2 5 2 7 3 2 1 1 1 7 8 0 0 8 3 5 5 7
# ...

# %%
import IPython.display as ipd
import random as rn
import numpy as np

count = 0
for i in range(10):
    l = rn.randint(0, len(y_test) - 1)
    index = 1  # Replace with the desired index from the X_mfcc array
    audio_path = df['speech'].iloc[index]  # Use iloc accessor to get the file path at the desired index
    
    # Make a prediction using your model
    input_data = x_test[l]  # Replace with the desired input data for making a prediction
    predicted_output = model.predict(np.array([input_data]))

    # Convert the predicted output to the corresponding class index
    predicted_class_index = np.argmax(predicted_output, axis=-1)
    
    # Create an array with the same shape as the one-hot encoded labels
    one_hot_array = np.zeros((1, enc.categories_[0].shape[0]))

    # Set the predicted class index to 1
    one_hot_array[0, predicted_class_index] = 1

    # Decode the one-hot encoded array to its corresponding label
    predicted_label = enc.inverse_transform(one_hot_array)
    print(f"Index: {index}, Audio path: {audio_path}")
    ipd.display(ipd.Audio(audio_path))
# Out:
# 1/1 [==============================] - 0s 26ms/step
# Index: 1, Audio path: /content/drive/MyDrive/SR1/OAF_neutral/OAF_cause_neutral.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 1/1 [==============================] - 0s 26ms/step
# Index: 1, Audio path: /content/drive/MyDrive/SR1/OAF_neutral/OAF_cause_neutral.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 1/1 [==============================] - 0s 32ms/step
# Index: 1, Audio path: /content/drive/MyDrive/SR1/OAF_neutral/OAF_cause_neutral.wav
#                 <audio  controls="controls" >
# ...
